# %% [markdown]
# # Getting Started

# %%
# @title Install necessary packages.
# !pip install -U dopamine-rl
# Out:
# Requirement already satisfied: dopamine-rl in c:\python39\lib\site-packages (3.0.1)
# Collecting dopamine-rl
#   Using cached dopamine_rl-3.2.1-py3-none-any.whl (127 kB)
# Requirement already satisfied: opencv-python>=3.4.8.29 in c:\python39\lib\site-packages (from dopamine-rl) (4.5.2.52)
# Requirement already satisfied: numpy>=1.16.4 in c:\python39\lib\site-packages (from dopamine-rl) (1.19.5)
# Collecting pygame>=1.9.2
#   Using cached pygame-2.0.1-cp39-cp39-win_amd64.whl (5.2 MB)
# Requirement already satisfied: gin-config>=0.3.0 in c:\python39\lib\site-packages (from dopamine-rl) (0.4.0)
# Requirement already satisfied: absl-py>=0.9.0 in c:\python39\lib\site-packages (from dopamine-rl) (0.13.0)
# Collecting tf-slim>=1.0
#   Using cached tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
# Requirement already satisfied: pandas>=0.24.2 in c:\python39\lib\site-packages (from dopamine-rl) (1.2.4)
# Requirement already satisfied: Pillow>=7.0.0 in c:\users\apple\appdata\roaming\python\python39\site-packages (from dopamine-rl) (8.1.0)
# Collecting flax>=0.2.0
#   Using cached flax-0.3.4-py3-none-any.whl (183 kB)
# Requirement already satisfied: tensorflow>=2.2.0 in c:\python39\lib\site-packages (from dopamine-rl) (2.5.0)
# Collecting dopamine-rl
#   Using cached dopamine_rl-3.1.14-py3-none-any.whl (120 kB)
#   Using cached dopamine_rl-3.1.13-py3-none-any.whl (119 kB)
#   Using cached dopamine_rl-3.1.10-py3-none-any.whl (119 kB)
#   Using cached dopamine_rl-3.1.9-py3-none-any.whl (118 kB)
#   Using cached dopamine_rl-3.1.8-py3-none-any.whl (117 kB)
#   Using cached dopamine_rl-3.1.7-py3-none-any.whl (117 kB)
#   Using cached dopamine_rl-3.1.6-py3-none-any.whl (117 kB)
#   Using cached dopamine_rl-3.1.5-py3-none-any.whl (117 kB)
#   Using cached dopamine_rl-3.1.4-py3-none-any.whl (117 kB)
#   Using cached dopamine_rl-3.1.3-py3-none-any.whl (117 kB)
#   Using cached dopamine_rl-3.1.2-py3-none-any.whl (111 kB)
#   Using cached dopamine_rl-3.1.1-py3-none-any.whl (112 kB)
#   Using cached dopamine_rl-3.1.0-py3-none-any.whl (90 kB)
# Requirement already satisfied: gym>=0.10.5 in c:\python39\lib\site-packages (from dopamine-rl) (0.18.3)
# Requirement already satisfied: six in c:\python39\lib\site-packages (from absl-py>=0.9.0->dopamine-rl) (1.15.0)
# Requirement already satisfied: scipy in c:\python39\lib\site-packages (from gym>=0.10.5->dopamine-rl) (1.6.3)
# Requirement already satisfied: pyglet<=1.5.15,>=1.4.0 in c:\python39\lib\site-packages (from gym>=0.10.5->dopamine-rl) (1.5.15)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in c:\python39\lib\site-packages (from gym>=0.10.5->dopamine-rl) (1.6.0)
# WARNING: You are using pip version 21.1.2; however, version 21.2.3 is available.
# You should consider upgrading via the 'c:\python39\python.exe -m pip install --upgrade pip' command.

# %%
pip install gin-config==0.1.1
# Out:
# Requirement already satisfied: gin-config==0.1.1 in c:\users\apple\anaconda3\lib\site-packages (0.1.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\apple\anaconda3\lib\site-packages (from gin-config==0.1.1) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# @title Necessary imports and globals.
import numpy as np
import os
from dopamine.agents.dqn import dqn_agent
from dopamine.discrete_domains import run_experiment
from dopamine.colab import utils as colab_utils
from absl import flags
import gin.tf
import pandas as pd

BASE_PATH = 'running-data'  # @param
GAME = 'ChopperCommand'  # @param

# %%
experimental_data = colab_utils.load_baselines('./baselines-data/')

# %%
# !python -m atari_py.import_roms roms
# Out:
# copying montezuma_revenge.bin from roms/Montezuma's Revenge - Featuring Panama Joe (1984) (Parker Brothers - JWDA, Henry Will IV) (PB5760) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/montezuma_revenge.bin
# copying double_dunk.bin from roms/Double Dunk (Super Basketball) (1989) (Atari, Matthew L. Hubbard) (CX26159) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/double_dunk.bin
# copying pacman.bin from roms/Pac-Man (1982) (Atari, Tod Frye) (CX2646) (PAL).bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/pacman.bin
# copying atlantis.bin from roms/Atlantis (Lost City of Atlantis) (1982) (Imagic, Dennis Koble) (720103-1A, 720103-1B, IA3203, IX-010-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/atlantis.bin
# copying ms_pacman.bin from roms/Ms. Pac-Man (1983) (Atari - GCC, Mark Ackerman, Glenn Parker) (CX2675) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/ms_pacman.bin
# copying defender.bin from roms/Defender (1982) (Atari, Robert C. Polaro, Alan J. Murphy - Sears) (CX2609 - 49-75186) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/defender.bin
# copying gopher.bin from roms/Gopher (Gopher Attack) (1982) (U.S. Games Corporation - JWDA, Sylvia Day, Todd Marshall, Robin McDaniel, Henry Will IV) (VC2001) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/gopher.bin
# copying qbert.bin from roms/Q-bert (1987) (Atari) (CX26150).bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/qbert.bin
# copying donkey_kong.bin from roms/Donkey Kong (1987) (Atari) (CX26143).bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/donkey_kong.bin
# copying keystone_kapers.bin from roms/Keystone Kapers - Raueber und Gendarm (1983) (Activision, Garry Kitchen - Ariola) (EAX-025, EAX-025-04I - 711 025-725) (PAL).bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/keystone_kapers.bin
# copying crazy_climber.bin from roms/Crazy Climber (1983) (Atari - Roklan, Joe Gaucher, Alex Leavens) (CX2683) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/crazy_climber.bin
# copying private_eye.bin from roms/Private Eye (1984) (Activision, Bob Whitehead) (AG-034-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/private_eye.bin
# copying frostbite.bin from roms/Frostbite (1983) (Activision, Steve Cartwright) (AX-031) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/frostbite.bin
# copying chopper_command.bin from roms/Chopper Command (1982) (Activision, Bob Whitehead) (AX-015, AX-015-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/chopper_command.bin
# copying berzerk.bin from roms/Berzerk (1982) (Atari, Dan Hitchens - Sears) (CX2650 - 49-75168) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/berzerk.bin
# copying kaboom.bin from roms/Kaboom! (Paddle) (1981) (Activision, Larry Kaplan, David Crane) (AG-010, AG-010-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/kaboom.bin
# copying alien.bin from roms/Alien (1982) (20th Century Fox Video Games, Douglas 'Dallas North' Neubauer) (11006) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/alien.bin
# copying frogger.bin from roms/Frogger (1982) (Parker Brothers, Ed English, David Lamkins) (PB5300) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/frogger.bin
# copying video_pinball.bin from roms/Pinball (AKA Video Pinball) (Zellers).bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/video_pinball.bin
# copying beam_rider.bin from roms/Beamrider (1984) (Activision - Cheshire Engineering, David Rolfe, Larry Zwick) (AZ-037-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/beam_rider.bin
# copying galaxian.bin from roms/Galaxian (1983) (Atari - GCC, Mark Ackerman, Tom Calderwood, Glenn Parker) (CX2684) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/galaxian.bin
# copying kangaroo.bin from roms/Kangaroo (1983) (Atari - GCC, Kevin Osborn) (CX2689) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/kangaroo.bin
# copying carnival.bin from roms/Carnival (1982) (Coleco - Woodside Design Associates, Steve 'Jessica Stevens' Kitchen) (2468) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/carnival.bin
# copying lost_luggage.bin from roms/Lost Luggage (Airport Mayhem) (1982) (Apollo - Games by Apollo, Larry Minor, Ernie Runyon, Ed Salvo) (AP-2004) [no opening scene] ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/lost_luggage.bin
# copying elevator_action.bin from roms/Elevator Action (1983) (Atari, Dan Hitchens) (CX26126) (Prototype) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/elevator_action.bin
# copying pitfall.bin from roms/Pitfall! - Pitfall Harry's Jungle Adventure (Jungle Runner) (1982) (Activision, David Crane) (AX-018, AX-018-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/pitfall.bin
# copying breakout.bin from roms/Breakout - Breakaway IV (Paddle) (1978) (Atari, Brad Stewart - Sears) (CX2622 - 6-99813, 49-75107) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/breakout.bin
# copying jamesbond.bin from roms/James Bond 007 (James Bond Agent 007) (1984) (Parker Brothers - On-Time Software, Joe Gaucher, Louis Marbel) (PB5110) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/jamesbond.bin
# copying assault.bin from roms/Assault (AKA Sky Alien) (1983) (Bomb - Onbase) (CA281).bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/assault.bin
# copying asterix.bin from roms/Asterix (AKA Taz) (07-27-1983) (Atari, Jerome Domurat, Steve Woita) (CX2696) (Prototype).bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/asterix.bin
# copying gravitar.bin from roms/Gravitar (1983) (Atari, Dan Hitchens, Mimi Nyden) (CX2685) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/gravitar.bin
# copying koolaid.bin from roms/Kool-Aid Man (Kool Aid Pitcher Man) (1983) (M Network, Stephen Tatsumi, Jane Terjung - Kool Aid) (MT4648) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/koolaid.bin
# copying bank_heist.bin from roms/Bank Heist (Bonnie & Clyde, Cops 'n' Robbers, Hold-Up, Roaring 20's) (1983) (20th Century Fox Video Games, Bill Aspromonte) (11012) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/bank_heist.bin
# copying centipede.bin from roms/Centipede (1983) (Atari - GCC) (CX2676) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/centipede.bin
# copying bowling.bin from roms/Bowling (1979) (Atari, Larry Kaplan - Sears) (CX2628 - 6-99842, 49-75117) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/bowling.bin
# copying king_kong.bin from roms/King Kong (1982) (Tigervision - Software Electronics Corporation, Karl T. Olinger - Teldec) (7-001 - 3.60001 VE) (PAL).bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/king_kong.bin
# copying laser_gates.bin from roms/Laser Gates (AKA Innerspace) (1983) (Imagic, Dan Oliver) (720118-2A, 13208, EIX-007-04I) (PAL).bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/laser_gates.bin
# copying boxing.bin from roms/Boxing - La Boxe (1980) (Activision, Bob Whitehead) (AG-002, CAG-002, AG-002-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/boxing.bin
# copying adventure.bin from roms/Adventure (1980) (Atari, Warren Robinett) (CX2613, CX2613P) (PAL).bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/adventure.bin
# copying phoenix.bin from roms/Phoenix (1983) (Atari - GCC, Mike Feinstein, John Mracek) (CX2673) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/phoenix.bin
# copying freeway.bin from roms/Freeway (1981) (Activision, David Crane) (AG-009, AG-009-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/freeway.bin
# copying kung_fu_master.bin from roms/Kung-Fu Master (1987) (Activision - Imagineering, Dan Kitchen, Garry Kitchen) (AG-039-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/kung_fu_master.bin
# copying krull.bin from roms/Krull (1983) (Atari, Jerome Domurat, Dave Staugas) (CX2682) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/krull.bin
# copying ice_hockey.bin from roms/Ice Hockey - Le Hockey Sur Glace (1981) (Activision, Alan Miller) (AX-012, CAX-012, AX-012-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/ice_hockey.bin
# copying air_raid.bin from roms/Air Raid (Men-A-Vision) (PAL) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/air_raid.bin
# copying journey_escape.bin from roms/Journey Escape (1983) (Data Age, J. Ray Dettling) (112-006) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/journey_escape.bin
# copying battle_zone.bin from roms/Battlezone (1983) (Atari - GCC, Mike Feinstein, Brad Rice) (CX2681) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/battle_zone.bin
# copying hero.bin from roms/H.E.R.O. (1984) (Activision, John Van Ryzin) (AZ-036-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/hero.bin
# copying enduro.bin from roms/Enduro (1983) (Activision, Larry Miller) (AX-026, AX-026-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/enduro.bin
# copying mr_do.bin from roms/Mr. Do! (1983) (CBS Electronics, Ed English) (4L4478) (PAL).bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/mr_do.bin
# copying fishing_derby.bin from roms/Fishing Derby (1980) (Activision, David Crane) (AG-004) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/fishing_derby.bin
# copying amidar.bin from roms/Amidar (1982) (Parker Brothers, Ed Temple) (PB5310) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/amidar.bin
# copying pooyan.bin from roms/Pooyan (1983) (Konami) (RC 100-X 02) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/pooyan.bin
# copying demon_attack.bin from roms/Demon Attack (Death from Above) (1982) (Imagic, Rob Fulop) (720000-200, 720101-1B, 720101-1C, IA3200, IA3200C, IX-006-04) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/demon_attack.bin
# copying asteroids.bin from roms/Asteroids (1981) (Atari, Brad Stewart - Sears) (CX2649 - 49-75163) [no copyright] ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/asteroids.bin
# copying name_this_game.bin from roms/Name This Game (Guardians of Treasure) (1983) (U.S. Games Corporation - JWDA, Roger Booth, Sylvia Day, Ron Dubren, Todd Marshall, Robin McDaniel, Wes Trager, Henry Will IV) (VC1007) ~.bin to /usr/local/lib/python3.7/site-packages/atari_py/atari_roms/name_this_game.bin

# %% [markdown]
# # DQN Prioritized

# %%
LOG_PATH = os.path.join(BASE_PATH, 'prioritized_dqn', GAME)

# %%
# @title Create the DQN with prioritized replay
from dopamine.replay_memory import prioritized_replay_buffer
import tensorflow as tf

class PrioritizedDQNAgent(dqn_agent.DQNAgent):
  def __init__(self, sess, num_actions):
    """This maintains all the DQN default argument values."""
    super().__init__(sess, num_actions, tf_device='/gpu:0')
    self._replay_scheme = 'prioritized'

  def _build_replay_buffer(self, use_staging):
    return prioritized_replay_buffer.WrappedPrioritizedReplayBuffer(
        observation_shape=self.observation_shape,
        stack_size=self.stack_size,
        use_staging=use_staging,
        update_horizon=self.update_horizon,
        gamma=self.gamma,
        observation_dtype=self.observation_dtype.as_numpy_dtype)

  def _build_train_op(self):
    """Builds a training op.
    Returns:
      train_op: An op performing one step of training from replay data.
    """
    replay_action_one_hot = tf.one_hot(
        self._replay.actions, self.num_actions, 1., 0., name='action_one_hot')
    replay_chosen_q = tf.reduce_sum(
        self._replay_net_outputs.q_values * replay_action_one_hot,
        axis=1,
        name='replay_chosen_q')

    target = tf.stop_gradient(self._build_target_q_op())
    loss = tf.compat.v1.losses.huber_loss(
        target, replay_chosen_q, reduction=tf.losses.Reduction.NONE)
    # The original prioritized experience replay uses a linear exponent
    # schedule 0.4 -> 1.0. Comparing the schedule to a fixed exponent of 0.5
    # on 5 games (Asterix, Pong, Q*Bert, Seaquest, Space Invaders) suggested
    # a fixed exponent actually performs better, except on Pong.
    probs = self._replay.transition['sampling_probabilities']
    loss_weights = 1.0 / tf.sqrt(probs + 1e-10)
    loss_weights /= tf.reduce_max(loss_weights)

    # Rainbow and prioritized replay are parametrized by an exponent alpha,
    # but in both cases it is set to 0.5 - for simplicity's sake we leave it
    # as is here, using the more direct tf.sqrt(). Taking the square root
    # "makes sense", as we are dealing with a squared loss.
    # Add a small nonzero value to the loss to avoid 0 priority items. While
    # technically this may be okay, setting all items to 0 priority will cause
    # troubles, and also result in 1.0 / 0.0 = NaN correction terms.
    update_priorities_op = self._replay.tf_set_priority(
        self._replay.indices, tf.sqrt(loss + 1e-10))

    # Weight the loss by the inverse priorities.
    loss = loss_weights * loss
    
    with tf.control_dependencies([update_priorities_op]):
      if self.summary_writer is not None:
        with tf.compat.v1.variable_scope('Losses'):
          tf.compat.v1.summary.scalar('HuberLoss', tf.reduce_mean(loss))
      return self.optimizer.minimize(tf.reduce_mean(loss))

  def _store_transition(self,
                        last_observation,
                        action,
                        reward,
                        is_terminal,
                        priority=None):
    priority = self._replay.memory.sum_tree.max_recorded_priority
    if not self.eval_mode:
      self._replay.add(last_observation, action, reward, is_terminal, priority)
def create_prioritized_dqn_agent(sess, environment, summary_writer=None):
  """The Runner class will expect a function of this type to create an agent."""
  return PrioritizedDQNAgent(sess, num_actions=environment.action_space.n)

prioritized_dqn_config = """
import dopamine.discrete_domains.atari_lib
import dopamine.discrete_domains.run_experiment
import dopamine.agents.dqn.dqn_agent
import dopamine.replay_memory.prioritized_replay_buffer
import gin.tf.external_configurables

DQNAgent.gamma = 0.99
DQNAgent.update_horizon = 1
DQNAgent.min_replay_history = 20000  # agent steps
DQNAgent.update_period = 4
DQNAgent.target_update_period = 8000  # agent steps
DQNAgent.epsilon_train = 0.01
DQNAgent.epsilon_eval = 0.001
DQNAgent.epsilon_decay_period = 250000  # agent steps
DQNAgent.tf_device = '/gpu:0'  # use '/cpu:*' for non-GPU version
DQNAgent.optimizer = @tf.train.RMSPropOptimizer()

tf.train.RMSPropOptimizer.learning_rate = 0.00025
tf.train.RMSPropOptimizer.decay = 0.95
tf.train.RMSPropOptimizer.momentum = 0.0
tf.train.RMSPropOptimizer.epsilon = 0.00001
tf.train.RMSPropOptimizer.centered = True

atari_lib.create_atari_environment.game_name = '{}'
# Sticky actions with probability 0.25, as suggested by (Machado et al., 2017).
atari_lib.create_atari_environment.sticky_actions = True
create_agent.agent_name = 'dqn'
Runner.num_iterations = 200
Runner.training_steps = 250000  # agent steps
Runner.evaluation_steps = 125000  # agent steps
Runner.max_steps_per_episode = 27000  # agent steps

WrappedPrioritizedReplayBuffer.replay_capacity = 1000000
WrappedPrioritizedReplayBuffer.batch_size = 32
""".format(GAME)
gin.parse_config(prioritized_dqn_config, skip_unknown=False)

# Create the runner class with this agent. We use very small numbers of steps
# to terminate quickly, as this is mostly meant for demonstrating how one can
# use the framework.
prioritized_dqn_runner = run_experiment.TrainRunner(LOG_PATH, create_prioritized_dqn_agent)
# Out:
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\compat\v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Restoring parameters from running-data\prioritized_dqn\BattleZone\checkpoints\tf_ckpt-90
# INFO:tensorflow:Restoring parameters from running-data\prioritized_dqn\BattleZone\checkpoints\tf_ckpt-90

# %%
# @title Train MyRandomDQNAgent.
print('Will train agent, please be patient, may be a while...')
prioritized_dqn_runner.run_experiment()
print('Done training!')
# Out:
# Will train agent, please be patient, may be a while...
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\training\saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\training\saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Steps executed: 195168 Episode length: 2015 Return: 17000.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-19a8f4d3cb6a> in <module>
#       1 # @title Train MyRandomDQNAgent.
#       2 print('Will train agent, please be patient, may be a while...')
# ----> 3 prioritized_dqn_runner.run_experiment()
#       4 print('Done training!')
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in run_experiment(self)
#     523
#     524     for iteration in range(self._start_iteration, self._num_iterations):
# --> 525       statistics = self._run_one_iteration(iteration)
#     526       self._log_experiment(iteration, statistics)
#     527       self._checkpoint_experiment(iteration)
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_one_iteration(self, iteration)
#     570     statistics = iteration_statistics.IterationStatistics()
#     571     num_episodes_train, average_reward_train, average_steps_per_second = (
# --> 572         self._run_train_phase(statistics))
#     573
#     574     self._save_tensorboard_summaries(iteration, num_episodes_train,
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_train_phase(self, statistics)
#     398     start_time = time.time()
#     399     number_steps, sum_returns, num_episodes = self._run_one_phase(
# --> 400         self._training_steps, statistics, 'train')
#     401     average_return = sum_returns / num_episodes if num_episodes > 0 else 0.0
#     402     statistics.append({'train_average_return': average_return})
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_one_phase(self, min_steps, statistics, run_mode_str)
#     366
#     367     while step_count < min_steps:
# --> 368       episode_length, episode_return = self._run_one_episode()
#     369       statistics.append({
#     370           '{}_episode_lengths'.format(run_mode_str): episode_length,
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_one_episode(self)
#     339         action = self._agent.begin_episode(observation)
#     340       else:
# --> 341         action = self._agent.step(reward, observation)
#     342
#     343     self._end_episode(reward, is_terminal)
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\agents\dqn\dqn_agent.py in step(self, reward, observation)
#     369     if not self.eval_mode:
#     370       self._store_transition(self._last_observation, self.action, reward, False)
# --> 371       self._train_step()
#     372
#     373     self.action = self._select_action()
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\agents\dqn\dqn_agent.py in _train_step(self)
#     424     if self._replay.memory.add_count > self.min_replay_history:
#     425       if self.training_steps % self.update_period == 0:
# --> 426         self._sess.run(self._train_op)
#     427         if (self.summary_writer is not None and
#     428             self.training_steps > 0 and
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\client\session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow_core\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# @title Load the training logs.
prioritized_dqn_data = colab_utils.read_experiment(
    LOG_PATH, verbose=True, summary_keys=['train_episode_returns'])
prioritized_dqn_data['agent'] = 'DQN Prioritized'
prioritized_dqn_data['run_number'] = 1
experimental_data[GAME] = experimental_data[GAME].merge(prioritized_dqn_data, how='outer')
# Out:
# Reading statistics from: running-data\prioritized_dqn\BattleZone\logs\log_90

# %%
data = experimental_data[GAME]
data[data['agent'] == 'dqn']

comparison = pd.concat([data[data['agent'] == 'dqn'], data[data['agent'] == 'DQN Prioritized']])

# %%
# @title Plot training results.

import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16,8))
sns.lineplot(
    x='iteration', y='train_episode_returns', hue='agent',
    data=comparison, ax=ax)
plt.title(GAME)
plt.show()

# %% [markdown]
# # DQN Plain

# %%
LOG_PATH = os.path.join(BASE_PATH, 'plain_dqn', GAME)

# %%
# @title Create the DQN with Plain setup
from dopamine.replay_memory import prioritized_replay_buffer
import tensorflow as tf

def create_plain_dqn_agent(sess, environment, summary_writer=None):
  """The Runner class will expect a function of this type to create an agent."""
  return dqn_agent.DQNAgent(sess, num_actions=environment.action_space.n)

plain_dqn_config = """
import dopamine.discrete_domains.atari_lib
import dopamine.discrete_domains.run_experiment
import dopamine.agents.dqn.dqn_agent
import dopamine.replay_memory.circular_replay_buffer
import gin.tf.external_configurables

DQNAgent.gamma = 0.99
DQNAgent.update_horizon = 1
DQNAgent.min_replay_history = 20000  # agent steps
DQNAgent.update_period = 4
DQNAgent.target_update_period = 8000  # agent steps
DQNAgent.epsilon_train = 0.01
DQNAgent.epsilon_eval = 0.001
DQNAgent.epsilon_decay_period = 250000  # agent steps
DQNAgent.tf_device = '/gpu:0'  # use '/cpu:*' for non-GPU version
DQNAgent.optimizer = @tf.train.RMSPropOptimizer()

tf.train.RMSPropOptimizer.learning_rate = 0.00025
tf.train.RMSPropOptimizer.decay = 0.95
tf.train.RMSPropOptimizer.momentum = 0.0
tf.train.RMSPropOptimizer.epsilon = 0.00001
tf.train.RMSPropOptimizer.centered = True

atari_lib.create_atari_environment.game_name = '{}'
# Sticky actions with probability 0.25, as suggested by (Machado et al., 2017).
atari_lib.create_atari_environment.sticky_actions = True
create_agent.agent_name = 'dqn'
Runner.num_iterations = 200
Runner.training_steps = 250000  # agent steps
Runner.evaluation_steps = 125000  # agent steps
Runner.max_steps_per_episode = 27000  # agent steps

WrappedReplayBuffer.replay_capacity = 1000000
WrappedReplayBuffer.batch_size = 32
""".format(GAME)
gin.parse_config(plain_dqn_config, skip_unknown=False)

# Create the runner class with this agent. We use very small numbers of steps
# to terminate quickly, as this is mostly meant for demonstrating how one can
# use the framework.
plain_dqn_runner = run_experiment.TrainRunner(LOG_PATH, create_plain_dqn_agent)
# Out:
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow\python\training\rmsprop.py:123: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow\python\training\rmsprop.py:123: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# @title Train MyRandomDQNAgent.
print('Will train agent, please be patient, may be a while...')
plain_dqn_runner.run_experiment()
print('Done training!')
# Out:
# Will train agent, please be patient, may be a while...
# Steps executed: 30698 Episode length: 285 Return: 500.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0806886f9a22> in <module>
#       1 # @title Train MyRandomDQNAgent.
#       2 print('Will train agent, please be patient, may be a while...')
# ----> 3 plain_dqn_runner.run_experiment()
#       4 print('Done training!')
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in run_experiment(self)
#     523
#     524     for iteration in range(self._start_iteration, self._num_iterations):
# --> 525       statistics = self._run_one_iteration(iteration)
#     526       self._log_experiment(iteration, statistics)
#     527       self._checkpoint_experiment(iteration)
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_one_iteration(self, iteration)
#     570     statistics = iteration_statistics.IterationStatistics()
#     571     num_episodes_train, average_reward_train, average_steps_per_second = (
# --> 572         self._run_train_phase(statistics))
#     573
#     574     self._save_tensorboard_summaries(iteration, num_episodes_train,
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_train_phase(self, statistics)
#     398     start_time = time.time()
#     399     number_steps, sum_returns, num_episodes = self._run_one_phase(
# --> 400         self._training_steps, statistics, 'train')
#     401     average_return = sum_returns / num_episodes if num_episodes > 0 else 0.0
#     402     statistics.append({'train_average_return': average_return})
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_one_phase(self, min_steps, statistics, run_mode_str)
#     366
#     367     while step_count < min_steps:
# --> 368       episode_length, episode_return = self._run_one_episode()
#     369       statistics.append({
#     370           '{}_episode_lengths'.format(run_mode_str): episode_length,
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_one_episode(self)
#     339         action = self._agent.begin_episode(observation)
#     340       else:
# --> 341         action = self._agent.step(reward, observation)
#     342
#     343     self._end_episode(reward, is_terminal)
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\agents\dqn\dqn_agent.py in step(self, reward, observation)
#     369     if not self.eval_mode:
#     370       self._store_transition(self._last_observation, self.action, reward, False)
# --> 371       self._train_step()
#     372
#     373     self.action = self._select_action()
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\agents\dqn\dqn_agent.py in _train_step(self)
#     424     if self._replay.memory.add_count > self.min_replay_history:
#     425       if self.training_steps % self.update_period == 0:
# --> 426         self._sess.run(self._train_op)
#     427         if (self.summary_writer is not None and
#     428             self.training_steps > 0 and
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     966     try:
#     967       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 968                          run_metadata_ptr)
#     969       if run_metadata:
#     970         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1189     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1190       results = self._do_run(handle, final_targets, final_fetches,
# -> 1191                              feed_dict_tensor, options, run_metadata)
#    1192     else:
#    1193       results = []
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1367     if handle is None:
#    1368       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1369                            run_metadata)
#    1370     else:
#    1371       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1373   def _do_call(self, fn, *args):
#    1374     try:
# -> 1375       return fn(*args)
#    1376     except errors.OpError as e:
#    1377       message = compat.as_text(e.message)
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1358       self._extend_graph()
#    1359       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1360                                       target_list, run_metadata)
#    1361
#    1362     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1451     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1452                                             fetch_list, target_list,
# -> 1453                                             run_metadata)
#    1454
#    1455   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# @title Load the training logs.
plain_dqn_data = colab_utils.read_experiment(
    LOG_PATH, verbose=True, summary_keys=['train_episode_returns'])
plain_dqn_data['agent'] = 'DQN Plain'
plain_dqn_data['run_number'] = 1
experimental_data[GAME] = experimental_data[GAME].merge(plain_dqn_data, how='outer')
# Out:
# Reading statistics from: running-data/plain_dqn/Asterix//logs/log_6

# %%
# @title Plot training results.

import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16,8))
sns.lineplot(
    x='iteration', y='train_episode_returns', hue='agent',
    data=experimental_data[GAME], ax=ax)
plt.title(GAME)
plt.show()

# %% [markdown]
# # DQN Prioritized SR

# %%
LOG_PATH = os.path.join(BASE_PATH, 'prioritized_srdqn', GAME)

# %%
# @title Create the DQN with prioritized replay
from dopamine.replay_memory import prioritized_replay_buffer
import dopamine.discrete_domains.atari_lib.SRNetwork
import tensorflow as tf

class PrioritizedSRDQNAgent(dqn_agent.DQNAgent):
  def __init__(self, sess, num_actions):
    """This maintains all the DQN default argument values."""
    super().__init__(sess, num_actions)
    self._replay_scheme = 'prioritized'

  def _build_networks(self):
    """Builds the Q-value network computations needed for acting and training.

    These are:
      self.online_convnet: For computing the current state's Q-values.
      self.target_convnet: For computing the next state's target Q-values.
      self.sr_convnet: For computing the sr for state-action pair
      self._net_outputs: The actual Q-values.
      self._q_argmax: The action maximizing the current state's Q-values.
      self._replay_net_outputs: The replayed states' Q-values.
      self._replay_next_target_net_outputs: The replayed next states' target
        Q-values (see Mnih et al., 2015 for details).
    """

    # _network_template instantiates the model and returns the network object.
    # The network object can be used to generate different outputs in the graph.
    # At each call to the network, the parameters will be reused.
    self.online_convnet = self._create_network(name='Online')
    self.target_convnet = self._create_network(name='Target')
    self.sr_convnet = SRNetwork(self.num_actions, atari_lib.NATURE_DQN_STACK_SIZE)
    self._net_outputs = self.online_convnet(self.state_ph)
    # TODO(bellemare): Ties should be broken. They are unlikely to happen when
    # using a deep network, but may affect performance with a linear
    # approximation scheme.
    self._q_argmax = tf.argmax(self._net_outputs.q_values, axis=1)[0]
    self._replay_net_outputs = self.online_convnet(self._replay.states)
    self._replay_next_target_net_outputs = self.target_convnet(
        self._replay.next_states)

  def _build_replay_buffer(self, use_staging):
    return prioritized_replay_buffer.WrappedPrioritizedReplayBuffer(
        observation_shape=self.observation_shape,
        stack_size=self.stack_size,
        use_staging=use_staging,
        update_horizon=self.update_horizon,
        gamma=self.gamma,
        observation_dtype=self.observation_dtype.as_numpy_dtype)

  def _build_train_op(self):
    """Builds a training op.
    Returns:
      train_op: An op performing one step of training from replay data.
    """
    replay_action_one_hot = tf.one_hot(
        self._replay.actions, self.num_actions, 1., 0., name='action_one_hot')
    replay_chosen_q = tf.reduce_sum(
        self._replay_net_outputs.q_values * replay_action_one_hot,
        axis=1,
        name='replay_chosen_q')

    target = tf.stop_gradient(self._build_target_q_op())
    loss = tf.compat.v1.losses.huber_loss(
        target, replay_chosen_q, reduction=tf.losses.Reduction.NONE)
    # The original prioritized experience replay uses a linear exponent
    # schedule 0.4 -> 1.0. Comparing the schedule to a fixed exponent of 0.5
    # on 5 games (Asterix, Pong, Q*Bert, Seaquest, Space Invaders) suggested
    # a fixed exponent actually performs better, except on Pong.
    probs = self._replay.transition['sampling_probabilities']
    loss_weights = 1.0 / tf.sqrt(probs + 1e-10)
    loss_weights /= tf.reduce_max(loss_weights)

    # Rainbow and prioritized replay are parametrized by an exponent alpha,
    # but in both cases it is set to 0.5 - for simplicity's sake we leave it
    # as is here, using the more direct tf.sqrt(). Taking the square root
    # "makes sense", as we are dealing with a squared loss.
    # Add a small nonzero value to the loss to avoid 0 priority items. While
    # technically this may be okay, setting all items to 0 priority will cause
    # troubles, and also result in 1.0 / 0.0 = NaN correction terms.
    update_priorities_op = self._replay.tf_set_priority(
        self._replay.indices, tf.sqrt(loss + 1e-10))

    # Weight the loss by the inverse priorities.
    loss = loss_weights * loss
    
    with tf.control_dependencies([update_priorities_op]):
      if self.summary_writer is not None:
        with tf.compat.v1.variable_scope('Losses'):
          tf.compat.v1.summary.scalar('HuberLoss', tf.reduce_mean(loss))
      return self.optimizer.minimize(tf.reduce_mean(loss))

  def _store_transition(self,
                        last_observation,
                        action,
                        reward,
                        is_terminal,
                        priority=None):
    priority = self._replay.memory.sum_tree.max_recorded_priority
    if not self.eval_mode:
      self._replay.add(last_observation, action, reward, is_terminal, priority)
    
  def _record_observation(self, observation):
    """Records an observation and update state.

    Extracts a frame from the observation vector and overwrites the oldest
    frame in the state buffer.

    Args:
      observation: numpy array, an observation from the environment.
    """
    # Set current observation. We do the reshaping to handle environments
    # without frame stacking.
    self._observation = np.reshape(observation, self.observation_shape)
    # Swap out the oldest frame with the current frame.
    self.state = np.roll(self.state, -1, axis=-1)
    print(self.state.shape)
    self.state[0, ..., -1] = self._observation
    
def create_prioritized_srdqn_agent(sess, environment, summary_writer=None):
  """The Runner class will expect a function of this type to create an agent."""
  return PrioritizedSRDQNAgent(sess, num_actions=environment.action_space.n)

prioritized_srdqn_config = """
import dopamine.discrete_domains.atari_lib
import dopamine.discrete_domains.run_experiment
import dopamine.agents.dqn.dqn_agent
import dopamine.replay_memory.prioritized_replay_buffer
import gin.tf.external_configurables

DQNAgent.gamma = 0.99
DQNAgent.update_horizon = 1
DQNAgent.min_replay_history = 20000  # agent steps
DQNAgent.update_period = 4
DQNAgent.target_update_period = 8000  # agent steps
DQNAgent.epsilon_train = 0.01
DQNAgent.epsilon_eval = 0.001
DQNAgent.epsilon_decay_period = 250000  # agent steps
DQNAgent.tf_device = '/gpu:0'  # use '/cpu:*' for non-GPU version
DQNAgent.optimizer = @tf.train.RMSPropOptimizer()

tf.train.RMSPropOptimizer.learning_rate = 0.00025
tf.train.RMSPropOptimizer.decay = 0.95
tf.train.RMSPropOptimizer.momentum = 0.0
tf.train.RMSPropOptimizer.epsilon = 0.00001
tf.train.RMSPropOptimizer.centered = True

atari_lib.create_atari_environment.game_name = '{}'
# Sticky actions with probability 0.25, as suggested by (Machado et al., 2017).
atari_lib.create_atari_environment.sticky_actions = True
create_agent.agent_name = 'dqn'
Runner.num_iterations = 200
Runner.training_steps = 250000  # agent steps
Runner.evaluation_steps = 125000  # agent steps
Runner.max_steps_per_episode = 27000  # agent steps

WrappedPrioritizedReplayBuffer.replay_capacity = 1000000
WrappedPrioritizedReplayBuffer.batch_size = 32
""".format(GAME)
gin.parse_config(prioritized_srdqn_config, skip_unknown=False)

# Create the runner class with this agent. We use very small numbers of steps
# to terminate quickly, as this is mostly meant for demonstrating how one can
# use the framework.
prioritized_srdqn_runner = run_experiment.TrainRunner(LOG_PATH, create_prioritized_srdqn_agent)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-17-e2702e77a508> in <module>
#       1 # @title Create the DQN with prioritized replay
#       2 from dopamine.replay_memory import prioritized_replay_buffer
# ----> 3 import dopamine.discrete_domains.atari_lib.SRNetwork
#       4 import tensorflow as tf
#       5
#
# ModuleNotFoundError: No module named 'dopamine.discrete_domains.atari_lib.SRNetwork'; 'dopamine.discrete_domains.atari_lib' is not a package

# %%
# @title Train MyRandomDQNAgent.
print('Will train agent, please be patient, may be a while...')
prioritized_srdqn_runner.run_experiment()
print('Done training!')
# Out:
# Will train agent, please be patient, may be a while...
# Steps executed: 522 Episode length: 277 Return: 250.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-cba92581b23a> in <module>
#       1 # @title Train MyRandomDQNAgent.
#       2 print('Will train agent, please be patient, may be a while...')
# ----> 3 prioritized_srdqn_runner.run_experiment()
#       4 print('Done training!')
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in run_experiment(self)
#     523
#     524     for iteration in range(self._start_iteration, self._num_iterations):
# --> 525       statistics = self._run_one_iteration(iteration)
#     526       self._log_experiment(iteration, statistics)
#     527       self._checkpoint_experiment(iteration)
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_one_iteration(self, iteration)
#     570     statistics = iteration_statistics.IterationStatistics()
#     571     num_episodes_train, average_reward_train, average_steps_per_second = (
# --> 572         self._run_train_phase(statistics))
#     573
#     574     self._save_tensorboard_summaries(iteration, num_episodes_train,
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_train_phase(self, statistics)
#     398     start_time = time.time()
#     399     number_steps, sum_returns, num_episodes = self._run_one_phase(
# --> 400         self._training_steps, statistics, 'train')
#     401     average_return = sum_returns / num_episodes if num_episodes > 0 else 0.0
#     402     statistics.append({'train_average_return': average_return})
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_one_phase(self, min_steps, statistics, run_mode_str)
#     366
#     367     while step_count < min_steps:
# --> 368       episode_length, episode_return = self._run_one_episode()
#     369       statistics.append({
#     370           '{}_episode_lengths'.format(run_mode_str): episode_length,
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_one_episode(self)
#     320     # Keep interacting until we reach a terminal state.
#     321     while True:
# --> 322       observation, reward, is_terminal = self._run_one_step(action)
#     323
#     324       total_reward += reward
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\run_experiment.py in _run_one_step(self, action)
#     288         environment.
#     289     """
# --> 290     observation, reward, is_terminal, _ = self._environment.step(action)
#     291     return observation, reward, is_terminal
#     292
#
# ~\anaconda3\envs\dopamine-need\lib\dopamine\discrete_domains\atari_lib.py in step(self, action)
#     459       # We bypass the Gym observation altogether and directly fetch the
#     460       # grayscale image from the ALE. This is a little faster.
# --> 461       _, reward, game_over, info = self.environment.step(action)
#     462       accumulated_reward += reward
#     463
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\gym\envs\atari\atari_env.py in step(self, a)
#     118             num_steps = self.np_random.randint(self.frameskip[0], self.frameskip[1])
#     119         for _ in range(num_steps):
# --> 120             reward += self.ale.act(action)
#     121         ob = self._get_obs()
#     122
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\atari_py\ale_python_interface.py in act(self, action)
#     150
#     151     def act(self, action):
# --> 152         return ale_lib.act(self.obj, int(action))
#     153
#     154     def game_over(self):
#
# KeyboardInterrupt:

# %% [markdown]
# # Upload to git

# %% [markdown]
# 1.   manually clone the repo to local computer
# 2.   download this file and overwrite into the repo
# 3.   resolve conflicts, push to origin

# %% [markdown]
# # Try out stable-baselines

# %%
from stable_baselines3.common.env_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3 import DQN

# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
env = make_atari_env('PongNoFrameskip-v4', n_envs=1, seed=0)
# Frame-stacking with 4 frames
env = VecFrameStack(env, n_stack=1)

model = DQN('CnnPolicy', env, verbose=1, device='cuda')
model.learn(total_timesteps=25000)

obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.
# C:\Users\apple\anaconda3\envs\dopamine-need\lib\site-packages\stable_baselines3\common\buffers.py:200: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 14.13GB > 7.82GB
#   "This system does not have apparently enough memory to store the complete "
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.6e+03  |
# |    ep_rew_mean      | -20.2    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 253      |
# |    time_elapsed     | 14       |
# |    total timesteps  | 3580     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.54e+03 |
# |    ep_rew_mean      | -20.4    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 254      |
# |    time_elapsed     | 27       |
# |    total timesteps  | 7024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.54e+03 |
# |    ep_rew_mean      | -20.5    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 253      |
# |    time_elapsed     | 41       |
# |    total timesteps  | 10543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.66e+03 |
# |    ep_rew_mean      | -20.2    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 255      |
# |    time_elapsed     | 57       |
# |    total timesteps  | 14541    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.77e+03 |
# |    ep_rew_mean      | -20.1    |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 252      |
# |    time_elapsed     | 74       |
# |    total timesteps  | 18715    |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9317b4a99906> in <module>
#      11
#      12 model = DQN('CnnPolicy', env, verbose=1, device='cuda')
# ---> 13 model.learn(total_timesteps=25000)
#      14
#      15 obs = env.reset()
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\stable_baselines3\dqn\dqn.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     234             tb_log_name=tb_log_name,
#     235             eval_log_path=eval_log_path,
# --> 236             reset_num_timesteps=reset_num_timesteps,
#     237         )
#     238
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     271                 learning_starts=self.learning_starts,
#     272                 replay_buffer=self.replay_buffer,
# --> 273                 log_interval=log_interval,
#     274             )
#     275
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     470
#     471                 # Rescale and perform action
# --> 472                 new_obs, reward, done, infos = env.step(action)
#     473
#     474                 self.num_timesteps += 1
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     161         """
#     162         self.step_async(actions)
# --> 163         return self.step_wait()
#     164
#     165     def get_images(self) -> Sequence[np.ndarray]:
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\stable_baselines3\common\vec_env\vec_transpose.py in step_wait(self)
#      46
#      47     def step_wait(self) -> VecEnvStepReturn:
# ---> 48         observations, rewards, dones, infos = self.venv.step_wait()
#      49
#      50         # Transpose the terminal observations
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\stable_baselines3\common\vec_env\vec_frame_stack.py in step_wait(self)
#      53
#      54     def step_wait(self) -> Tuple[np.ndarray, np.ndarray, np.ndarray, List[Dict[str, Any]]]:
# ---> 55         observations, rewards, dones, infos = self.venv.step_wait()
#      56         # Let pytype know that observation is not a dict
#      57         assert isinstance(observations, np.ndarray)
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      42         for env_idx in range(self.num_envs):
#      43             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
# ---> 44                 self.actions[env_idx]
#      45             )
#      46             if self.buf_dones[env_idx]:
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\gym\core.py in step(self, action)
#     232
#     233     def step(self, action):
# --> 234         return self.env.step(action)
#     235
#     236     def reset(self, **kwargs):
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\gym\core.py in step(self, action)
#     278
#     279     def step(self, action):
# --> 280         observation, reward, done, info = self.env.step(action)
#     281         return observation, self.reward(reward), done, info
#     282
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\gym\core.py in step(self, action)
#     266
#     267     def step(self, action):
# --> 268         observation, reward, done, info = self.env.step(action)
#     269         return self.observation(observation), reward, done, info
#     270
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\gym\core.py in step(self, action)
#     232
#     233     def step(self, action):
# --> 234         return self.env.step(action)
#     235
#     236     def reset(self, **kwargs):
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\stable_baselines3\common\atari_wrappers.py in step(self, action)
#      81
#      82     def step(self, action: int) -> GymStepReturn:
# ---> 83         obs, reward, done, info = self.env.step(action)
#      84         self.was_real_done = done
#      85         # check current lives, make loss of life terminal,
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\stable_baselines3\common\atari_wrappers.py in step(self, action)
#     137         done = None
#     138         for i in range(self._skip):
# --> 139             obs, reward, done, info = self.env.step(action)
#     140             if i == self._skip - 2:
#     141                 self._obs_buffer[0] = obs
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\gym\core.py in step(self, action)
#     232
#     233     def step(self, action):
# --> 234         return self.env.step(action)
#     235
#     236     def reset(self, **kwargs):
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\stable_baselines3\common\monitor.py in step(self, action)
#      95         if self.needs_reset:
#      96             raise RuntimeError("Tried to step environment that needs reset")
# ---> 97         observation, reward, done, info = self.env.step(action)
#      98         self.rewards.append(reward)
#      99         if done:
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\gym\wrappers\time_limit.py in step(self, action)
#      14     def step(self, action):
#      15         assert self._elapsed_steps is not None, "Cannot call env.step() before calling reset()"
# ---> 16         observation, reward, done, info = self.env.step(action)
#      17         self._elapsed_steps += 1
#      18         if self._elapsed_steps >= self._max_episode_steps:
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\gym\envs\atari\atari_env.py in step(self, a)
#     118             num_steps = self.np_random.randint(self.frameskip[0], self.frameskip[1])
#     119         for _ in range(num_steps):
# --> 120             reward += self.ale.act(action)
#     121         ob = self._get_obs()
#     122
#
# ~\anaconda3\envs\dopamine-need\lib\site-packages\atari_py\ale_python_interface.py in act(self, action)
#     150
#     151     def act(self, action):
# --> 152         return ale_lib.act(self.obj, int(action))
#     153
#     154     def game_over(self):
#
# KeyboardInterrupt:

# %%
env.close()

# %% [markdown]
# # Make the plot

# %%
pip install pickle5
# Out:
# Collecting pickle5
#   Downloading pickle5-0.0.11.tar.gz (132 kB)
# Building wheels for collected packages: pickle5
#   Building wheel for pickle5 (setup.py): started
#   Building wheel for pickle5 (setup.py): finished with status 'done'
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp36-cp36m-win_amd64.whl size=123893 sha256=fd147ad8052096874da0936cfda1956f100c73b8c38b1dfd6769f984e8478a2c
#   Stored in directory: c:\users\apple\appdata\local\pip\cache\wheels\f9\b7\be\bf9768ab0daa28fa4b386f3ad1bac5dd4d9c349c60e83b24e3
# Successfully built pickle5
# Installing collected packages: pickle5
# Successfully installed pickle5-0.0.11
# Note: you may need to restart the kernel to use updated packages.

# %%
GAME = 'StarGunner'
LOG_PATH = os.path.join(BASE_PATH, 'prioritized_srdqn_normalized', GAME)

# %%
# @title Load the training logs.
plain_dqn_data = colab_utils.read_experiment(
    LOG_PATH, verbose=True, summary_keys=['train_episode_returns'])
plain_dqn_data['agent'] = 'PER-SR-magnitude'
plain_dqn_data['run_number'] = 1
experimental_data[GAME] = experimental_data[GAME].merge(plain_dqn_data, how='outer')
# Out:
# Reading statistics from: running-data\prioritized_srdqn_normalized\StarGunner\logs\log_80

# %%
GAME = 'Boxing'
LOG_PATH = os.path.join(BASE_PATH, 'prioritized_srdqn_new', GAME)

# %%
plain_dqn_data = colab_utils.read_experiment(
    LOG_PATH, verbose=True, summary_keys=['train_episode_returns'])
plain_dqn_data['agent'] = 'PER-SR-new'
plain_dqn_data['run_number'] = 1
experimental_data[GAME] = experimental_data[GAME].merge(plain_dqn_data, how='outer')
# Out:
# Reading statistics from: running-data\prioritized_srdqn_new\ChopperCommand\logs\log_58

# %%
LOG_PATH = os.path.join(BASE_PATH, 'prioritized_dqn', GAME)

# %%
plain_dqn_data = colab_utils.read_experiment(
    LOG_PATH, verbose=True, summary_keys=['train_episode_returns'])
plain_dqn_data['agent'] = 'PER'
plain_dqn_data['run_number'] = 1
experimental_data[GAME] = experimental_data[GAME].merge(plain_dqn_data, how='outer')
# Out:
# Reading statistics from: running-data\prioritized_dqn\StarGunner\logs\log_162

# %%
data = experimental_data[GAME]
comparison = pd.concat([data[data['agent'] == 'PER'], data[data['agent'] == 'PER-SR-magnitude']])
# comparison = pd.concat([data[data['agent'] == 'PER'], data[data['agent'] == 'PER-SR-new']])
# comparison = pd.concat([data[data['agent'] == 'PER'], data[data['agent'] == 'PER-SR-magnitude'], data[data['agent'] == 'PER-SR-sample']])

# %%
# @title Plot training results.

import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16,8))
sns.lineplot(
    x='iteration', y='train_episode_returns', hue='agent',
    data=comparison, ax=ax)
plt.title(GAME)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-15dd2fbd65fe> in <module>
#       7 sns.lineplot(
#       8     x='iteration', y='train_episode_returns', hue='agent',
# ----> 9     data=comparison, ax=ax)
#      10 plt.title(GAME)
#      11 plt.show()
#
# NameError: name 'comparison' is not defined

# %%
def relative_performance(game):
    GAME = game
    LOG_PATH = os.path.join(BASE_PATH, 'prioritized_srdqn_normalized', GAME)
    
    # @title Load the training logs.
    plain_dqn_data = colab_utils.read_experiment(
    LOG_PATH, verbose=True, summary_keys=['train_episode_returns'])
    plain_dqn_data['agent'] = 'PER-SR-magnitude'
    plain_dqn_data['run_number'] = 1
    experimental_data[GAME] = experimental_data[GAME].merge(plain_dqn_data, how='outer')
    
    LOG_PATH = os.path.join(BASE_PATH, 'prioritized_dqn', GAME)
    plain_dqn_data = colab_utils.read_experiment(
    LOG_PATH, verbose=True, summary_keys=['train_episode_returns'])
    plain_dqn_data['agent'] = 'PER'
    plain_dqn_data['run_number'] = 1
    experimental_data[GAME] = experimental_data[GAME].merge(plain_dqn_data, how='outer')
    
    data = experimental_data[GAME]
    comparison = data[data['agent'] == 'PER-SR-magnitude']['train_episode_returns'].max() / data[data['agent'] == 'PER']['train_episode_returns'].max() - 1
    
    return comparison

# %%
relative_performance('BattleZone')
# Out:
# Reading statistics from: running-data\prioritized_srdqn_normalized\BattleZone\logs\log_199
# Reading statistics from: running-data\prioritized_dqn\BattleZone\logs\log_199
# 0.23530465338427953

# %%
games = ['Asterix', 'BattleZone', 'Berzerk', 'Boxing', 'StarGunner', 'Qbert', 'Robotank']
all_ratio = []
for game in games:
    ratio = relative_performance(game)
    all_ratio.append([game, ratio])
    
ratios = pd.DataFrame(all_ratio, columns=['game', 'ratio'])
# Out:
# Reading statistics from: running-data\prioritized_srdqn_normalized\Asterix\logs\log_199
# Reading statistics from: running-data\prioritized_dqn\Asterix\logs\log_194
# Reading statistics from: running-data\prioritized_srdqn_normalized\BattleZone\logs\log_199
# Reading statistics from: running-data\prioritized_dqn\BattleZone\logs\log_199
# Reading statistics from: running-data\prioritized_srdqn_normalized\Berzerk\logs\log_190
# Reading statistics from: running-data\prioritized_dqn\Berzerk\logs\log_199
# Reading statistics from: running-data\prioritized_srdqn_normalized\Boxing\logs\log_199
# Reading statistics from: running-data\prioritized_dqn\Boxing\logs\log_196
# Reading statistics from: running-data\prioritized_srdqn_normalized\StarGunner\logs\log_186
# Reading statistics from: running-data\prioritized_dqn\StarGunner\logs\log_199
# Reading statistics from: running-data\prioritized_srdqn_normalized\Qbert\logs\log_199
# Reading statistics from: running-data\prioritized_dqn\Qbert\logs\log_199
# Reading statistics from: running-data\prioritized_srdqn_normalized\Robotank\logs\log_199
# Reading statistics from: running-data\prioritized_dqn\Robotank\logs\log_199

# %%
ratios.head(10)
# Out:
#          game     ratio
# 0     Asterix -0.150088
# 1  BattleZone  0.235305
# 2     Berzerk  1.726458
# 3      Boxing  0.413607
# 4  StarGunner -0.103273
# 5       Qbert  4.754956
# 6    Robotank  6.158477

# %%
import seaborn as sns
import matplotlib.pyplot as plt

ax = ratios.sort_values(by=['ratio']).plot.bar(x="game", y="ratio")
ax.set_xlabel("")
ax.set_ylabel("Percentage change relative to PER")
ax.axhline(y = 0, color='k', lw=0.8, ls='--')
ax.get_legend().remove()

# set y axis in percentage
vals = ax.get_yticks()
ax.set_yticklabels(['{:,.0%}'.format(x) for x in vals])
plt.savefig('relativeperf.eps', format='eps')
# Out:
# [Text(0, 0, '-100%'),
#  Text(0, 0, '0%'),
#  Text(0, 0, '100%'),
#  Text(0, 0, '200%'),
#  Text(0, 0, '300%'),
#  Text(0, 0, '400%'),
#  Text(0, 0, '500%'),
#  Text(0, 0, '600%'),
#  Text(0, 0, '700%')]

# %%
def get_data(game):
    GAME = game
    LOG_PATH = os.path.join(BASE_PATH, 'prioritized_srdqn_normalized', GAME)
    
    # @title Load the training logs.
    plain_dqn_data = colab_utils.read_experiment(
    LOG_PATH, verbose=True, summary_keys=['train_episode_returns'])
    plain_dqn_data['agent'] = 'PER-SR-magnitude'
    plain_dqn_data['run_number'] = 1
    experimental_data[GAME] = experimental_data[GAME].merge(plain_dqn_data, how='outer')
    
    LOG_PATH = os.path.join(BASE_PATH, 'prioritized_dqn', GAME)
    plain_dqn_data = colab_utils.read_experiment(
    LOG_PATH, verbose=True, summary_keys=['train_episode_returns'])
    plain_dqn_data['agent'] = 'PER'
    plain_dqn_data['run_number'] = 1
    experimental_data[GAME] = experimental_data[GAME].merge(plain_dqn_data, how='outer')
    
    data = experimental_data[GAME]
    comparison = pd.concat([data[data['agent'] == 'PER'], data[data['agent'] == 'PER-SR-magnitude']])
    
    return comparison

# %%
games = ['Asterix', 'BattleZone', 'Berzerk', 'Boxing', 'StarGunner', 'Qbert', 'Robotank']
num_cols = 4
num_rows = 2
fig, axs = plt.subplots(num_rows, num_cols, figsize=(16,7))
fig.delaxes(axs[1, 3])
for i in range(len(games)):
    game = games[i]
    comparison = get_data(game)
    curr_ax = axs[i // num_cols, i % num_cols]
    sns.lineplot(x='iteration', y='train_episode_returns', hue='agent', data=comparison, ax=curr_ax)
    curr_ax.set_title(game)
    curr_ax.set(xlabel=None)
    curr_ax.set(ylabel=None)
    curr_ax.get_legend().remove()
    curr_ax.axes.get_xaxis().set_visible(False)

# add margins
fig.tight_layout()

# lines = []
# labels = []

# for ax in fig.axes:
#     axLine, axLabel = ax.get_legend_handles_labels()
#     lines.extend(axLine)
#     labels.extend(axLabel)
# fig.legend(lines, labels, loc = 'lower center')

plt.show()
# Out:
# Reading statistics from: running-data\prioritized_srdqn_normalized\Asterix\logs\log_199
# Reading statistics from: running-data\prioritized_dqn\Asterix\logs\log_194
# Reading statistics from: running-data\prioritized_srdqn_normalized\BattleZone\logs\log_199
# Reading statistics from: running-data\prioritized_dqn\BattleZone\logs\log_199
# Reading statistics from: running-data\prioritized_srdqn_normalized\Berzerk\logs\log_190
# Reading statistics from: running-data\prioritized_dqn\Berzerk\logs\log_199
# Reading statistics from: running-data\prioritized_srdqn_normalized\Boxing\logs\log_199
# Reading statistics from: running-data\prioritized_dqn\Boxing\logs\log_196
# Reading statistics from: running-data\prioritized_srdqn_normalized\StarGunner\logs\log_186
# Reading statistics from: running-data\prioritized_dqn\StarGunner\logs\log_199
# Reading statistics from: running-data\prioritized_srdqn_normalized\Qbert\logs\log_199
# Reading statistics from: running-data\prioritized_dqn\Qbert\logs\log_199
# Reading statistics from: running-data\prioritized_srdqn_normalized\Robotank\logs\log_199
# Reading statistics from: running-data\prioritized_dqn\Robotank\logs\log_199
