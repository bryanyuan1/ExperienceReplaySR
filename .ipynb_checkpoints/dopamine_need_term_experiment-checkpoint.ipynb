# %%
# @title Install necessary packages.
# !pip install -U dopamine-rl
# Out:
# Looking in indexes: http://mirrors.tencentyun.com/pypi/simple
# Collecting dopamine-rl
#   Downloading http://mirrors.tencentyun.com/pypi/packages/4e/60/b7db9ae46d8061a63a4dd7ddc58cb5c7126d808b20517d9fc6a7952ef636/dopamine_rl-3.1.14-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 9.9 MB/s eta 0:00:01
# Collecting gym[atari]>=0.13.1
#   Downloading http://mirrors.tencentyun.com/pypi/packages/1a/db/816fd52c0c196b6799e89d1f65b6c74fead2707cf7d447f3f354edfa7a44/gym-0.18.3.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 13.5 MB/s eta 0:00:01
# Collecting tensorflow>=2.2.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/ef/17/01bdb5f1e47c1a5b39c58f138189df98e07feccf86935a834505f333ac6e/tensorflow-2.5.0-cp36-cp36m-manylinux2010_x86_64.whl (454.3 MB)
#      |████████████████████████████████| 454.3 MB 64 kB/s eta 0:00:0105   |██▊                             | 38.3 MB 127 kB/s eta 0:54:19     |████████████▊                   | 180.2 MB 63 kB/s eta 1:12:14     |████████████████                | 227.3 MB 51 kB/s eta 1:13:56     |█████████████████████████████▎  | 415.1 MB 45 kB/s eta 0:14:15
# Collecting flax>=0.2.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/f6/21/21ca1f4831ac24646578d2545c4db9a8369b9da4a4b7dcf067feee312b45/flax-0.3.4-py3-none-any.whl (183 kB)
#      |████████████████████████████████| 183 kB 7.9 MB/s eta 0:00:01
# Collecting pygame>=1.9.2
#   Downloading http://mirrors.tencentyun.com/pypi/packages/01/da/4ff439558641a26dd29b04c25947e6c0ace041f56b2aa2ef1134edab06b8/pygame-2.0.1-cp36-cp36m-manylinux1_x86_64.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 20.7 MB/s eta 0:00:01
# Collecting opencv-python>=3.4.8.29
#   Downloading http://mirrors.tencentyun.com/pypi/packages/b5/18/03d4b96fab9b56ce84e641aa0426afff9b54bb7685c342594c934bce5e7b/opencv_python-4.5.2.54-cp36-cp36m-manylinux2014_x86_64.whl (51.0 MB)
#      |████████████████████████████████| 51.0 MB 41.7 MB/s eta 0:00:01     |███████████▍                    | 18.2 MB 20.6 MB/s eta 0:00:02     |███████████████████████████████▋| 50.4 MB 41.7 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: numpy>=1.16.4 in /opt/conda/envs/python3/lib/python3.6/site-packages (from dopamine-rl) (1.18.5)
# Collecting absl-py>=0.9.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/23/47/835652c7e19530973c73c65e652fc53bd05725d5a7cf9bb8706777869c1e/absl_py-0.13.0-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 9.6 MB/s eta 0:00:01
# Collecting tf-slim>=1.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/02/97/b0f4a64df018ca018cc035d44f2ef08f91e2e8aa67271f6f19633a015ff7/tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      |████████████████████████████████| 352 kB 22.0 MB/s eta 0:00:01
# Collecting gin-config>=0.3.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/d7/b1/c4950247902f430376c7d9c8a7811269150e66e0207b74330de181dd6779/gin_config-0.4.0-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 72.1 MB/s eta 0:00:01
# Collecting jax>=0.1.72
#   Downloading http://mirrors.tencentyun.com/pypi/packages/e4/ff/d31e4ea4fad188ee3e478e1cc303f0cbbe6da7d1b60434cfa80325b3cc92/jax-0.2.16.tar.gz (680 kB)
#      |████████████████████████████████| 680 kB 34.3 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: pandas>=0.24.2 in /opt/conda/envs/python3/lib/python3.6/site-packages (from dopamine-rl) (1.0.5)
# Collecting jaxlib>=0.1.51
#   Downloading http://mirrors.tencentyun.com/pypi/packages/dc/6b/6bbfae7c4899ec29e14ee91756c857b6eb8cb38f807e150f8ded9feec544/jaxlib-0.1.68-cp36-none-manylinux2010_x86_64.whl (46.2 MB)
#      |████████████████████████████████| 46.2 MB 56.4 MB/s eta 0:00:011    |█████████████████████▏          | 30.6 MB 404 kB/s eta 0:00:39
# Collecting Pillow>=7.0.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/89/d2/942af29f8494a1a3f4bc4f483d520f7c02ccae677f5f50cf76c6b3d827d8/Pillow-8.2.0-cp36-cp36m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 13.3 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: scipy in /opt/conda/envs/python3/lib/python3.6/site-packages (from gym[atari]>=0.13.1->dopamine-rl) (1.5.0)
# Collecting pyglet<=1.5.15,>=1.4.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/81/5e/aef9e460989e4b832215d5fcee3ea9b0629e9bce8607284d9c1021b6a251/pyglet-1.5.15-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 72.8 MB/s eta 0:00:01
# Collecting cloudpickle<1.7.0,>=1.2.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/e7/e3/898487e5dbeb612054cf2e0c188463acb358167fef749c53c8bb8918cea1/cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting atari_py~=0.2.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/af/cf/181870fd3cc7018ff488633d3b3951fe095ce1829cfb723537d980b2b36d/atari_py-0.2.9-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 69.9 MB/s eta 0:00:01
# Collecting google-pasta~=0.2
#   Downloading http://mirrors.tencentyun.com/pypi/packages/a3/de/c648ef6835192e6e2cc03f40b19eeda4382c49b5bafb43d88b931c4c74ac/google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 13.5 MB/s eta 0:00:01
# Collecting keras-preprocessing~=1.1.2
#   Downloading http://mirrors.tencentyun.com/pypi/packages/79/4c/7c3275a01e12ef9368a892926ab932b33bb13d55794881e3573482b378a7/Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 46.3 MB/s eta 0:00:01
# Collecting tensorboard~=2.5
#   Downloading http://mirrors.tencentyun.com/pypi/packages/44/f5/7feea02a3fb54d5db827ac4b822a7ba8933826b36de21880518250b8733a/tensorboard-2.5.0-py3-none-any.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 16.0 MB/s eta 0:00:01
# Collecting gast==0.4.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/b6/48/583c032b79ae5b3daa02225a675aeb673e58d2cb698e78510feceb11958c/gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting wheel~=0.35
#   Downloading http://mirrors.tencentyun.com/pypi/packages/65/63/39d04c74222770ed1589c0eaba06c05891801219272420b40311cd60c880/wheel-0.36.2-py2.py3-none-any.whl (35 kB)
# Collecting tensorflow-estimator<2.6.0,>=2.5.0rc0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/ec/78/b27f73e923becc6e79e18fe112cf75e3200d1ee35b0dba8fa46181bce56c/tensorflow_estimator-2.5.0-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 67.6 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: six~=1.15.0 in /opt/conda/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.2.0->dopamine-rl) (1.15.0)
# Collecting flatbuffers~=1.12.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/eb/26/712e578c5f14e26ae3314c39a1bdc4eb2ec2f4ddc89b708cf8e0a0d20423/flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting opt-einsum~=3.3.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/bc/19/404708a7e54ad2798907210462fd950c3442ea51acc8790f3da48d2bee8b/opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 62.5 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: protobuf>=3.9.2 in /opt/conda/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.2.0->dopamine-rl) (3.12.2)
# Requirement already satisfied, skipping upgrade: typing-extensions~=3.7.4 in /opt/conda/envs/python3/lib/python3.6/site-packages (from tensorflow>=2.2.0->dopamine-rl) (3.7.4.2)
# Collecting keras-nightly~=2.5.0.dev
#   Downloading http://mirrors.tencentyun.com/pypi/packages/aa/e7/53bc896aa4e11a87aac10a625c676b3a3d57d1c8d9929e4809d31fa0b7d5/keras_nightly-2.5.0.dev2021032900-py2.py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 47.3 MB/s eta 0:00:01
# Collecting grpcio~=1.34.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/ab/f5/3d3bcb82beae990021cbf6877456a1aab650e68c902194566edd6a73e37c/grpcio-1.34.1-cp36-cp36m-manylinux2014_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 9.7 MB/s eta 0:00:01
# Collecting astunparse~=1.6.3
#   Downloading http://mirrors.tencentyun.com/pypi/packages/2b/03/13dde6512ad7b4557eb792fbcf0c653af6076b81e5941d36ec61f7ce6028/astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting termcolor~=1.1.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting wrapt~=1.12.1
#   Downloading http://mirrors.tencentyun.com/pypi/packages/82/f7/e43cefbe88c5fd371f4cf0cf5eb3feccd07515af9fd6cf7dbf1d1793a797/wrapt-1.12.1.tar.gz (27 kB)
# Collecting h5py~=3.1.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/70/7a/e53e500335afb6b1aade11227cdf107fca54106a1dca5c9d13242a043f3b/h5py-3.1.0-cp36-cp36m-manylinux1_x86_64.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 31.4 MB/s eta 0:00:01
# Collecting optax
#   Downloading http://mirrors.tencentyun.com/pypi/packages/ca/04/464fa1d12562d191196f2f7f8112d65e22eaaa9a7e2b599f298aeba2ce27/optax-0.0.8-py3-none-any.whl (113 kB)
#      |████████████████████████████████| 113 kB 107.3 MB/s eta 0:00:01
# Collecting dataclasses; python_version < "3.7"
#   Downloading http://mirrors.tencentyun.com/pypi/packages/fe/ca/75fac5856ab5cfa51bbbcefa250182e50441074fdc3f803f6e76451fab43/dataclasses-0.8-py3-none-any.whl (19 kB)
# Collecting msgpack
#   Downloading http://mirrors.tencentyun.com/pypi/packages/0c/0d/b1d9d32d03ce38ba5e2a37fbae850afd4530a14cc441e8335f1865a03705/msgpack-1.0.2-cp36-cp36m-manylinux1_x86_64.whl (272 kB)
#      |████████████████████████████████| 272 kB 78.2 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: matplotlib in /opt/conda/envs/python3/lib/python3.6/site-packages (from flax>=0.2.0->dopamine-rl) (2.2.2)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /opt/conda/envs/python3/lib/python3.6/site-packages (from pandas>=0.24.2->dopamine-rl) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /opt/conda/envs/python3/lib/python3.6/site-packages (from pandas>=0.24.2->dopamine-rl) (2020.1)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in /opt/conda/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.2.0->dopamine-rl) (47.3.1.post20200616)
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/1a/c1/499e600ba0c618b451cd9c425ae1c177249940a2086316552fee7d86c954/tensorboard_plugin_wit-1.8.0-py3-none-any.whl (781 kB)
#      |████████████████████████████████| 781 kB 22.1 MB/s eta 0:00:01
# Collecting markdown>=2.6.8
#   Downloading http://mirrors.tencentyun.com/pypi/packages/6e/33/1ae0f71395e618d6140fbbc9587cc3156591f748226075e0f7d6f9176522/Markdown-3.3.4-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 56.9 MB/s eta 0:00:01
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading http://mirrors.tencentyun.com/pypi/packages/9d/d3/7541e89f1fc456eef157224f597a8bba22589db6369a03eaba68c11f07a0/google_auth_oauthlib-0.4.4-py2.py3-none-any.whl (18 kB)
# Collecting google-auth<2,>=1.6.3
#   Downloading http://mirrors.tencentyun.com/pypi/packages/c7/ef/6594c495bd51e2a9601a3d57d4a796f29bda8be42627613c7976ae587f97/google_auth-1.32.0-py2.py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 93.6 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /opt/conda/envs/python3/lib/python3.6/site-packages (from tensorboard~=2.5->tensorflow>=2.2.0->dopamine-rl) (2.24.0)
# Collecting werkzeug>=0.11.15
#   Downloading http://mirrors.tencentyun.com/pypi/packages/bd/24/11c3ea5a7e866bf2d97f0501d0b4b1c9bbeade102bb4b588f0d2919a5212/Werkzeug-2.0.1-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 1.5 MB/s eta 0:00:01
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/60/f9/802efd84988bffd9f644c03b6e66fde8e76c3aa33db4279ddd11c5d61f4b/tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 19.3 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: cached-property; python_version < "3.8" in /opt/conda/envs/python3/lib/python3.6/site-packages (from h5py~=3.1.0->tensorflow>=2.2.0->dopamine-rl) (1.5.1)
# Collecting chex>=0.0.4
#   Downloading http://mirrors.tencentyun.com/pypi/packages/f5/b9/445eb59ec23249acffc5322c79b07e20b12dbff45b9c1da6cdae9e947685/chex-0.0.7-py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 15.0 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /opt/conda/envs/python3/lib/python3.6/site-packages (from matplotlib->flax>=0.2.0->dopamine-rl) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /opt/conda/envs/python3/lib/python3.6/site-packages (from matplotlib->flax>=0.2.0->dopamine-rl) (2.4.7)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /opt/conda/envs/python3/lib/python3.6/site-packages (from matplotlib->flax>=0.2.0->dopamine-rl) (1.2.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /opt/conda/envs/python3/lib/python3.6/site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.2.0->dopamine-rl) (1.7.0)
# Collecting requests-oauthlib>=0.7.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/a3/12/b92740d845ab62ea4edf04d2f4164d82532b5a0b03836d4d4e71c6f3d379/requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading http://mirrors.tencentyun.com/pypi/packages/e9/93/0c0f002031f18b53af7a6166103c02b9c0667be528944137cc954ec921b3/rsa-4.7.2-py3-none-any.whl (34 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/bf/28/c4f5796c67ad06bb91d98d543a5e01805c1ff065e08871f78e52d2a331ad/cachetools-4.2.2-py3-none-any.whl (11 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading http://mirrors.tencentyun.com/pypi/packages/95/de/214830a981892a3e286c3794f41ae67a4495df1108c3da8a9f62159b9a9d/pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 15.7 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /opt/conda/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.2.0->dopamine-rl) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /opt/conda/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.2.0->dopamine-rl) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.2.0->dopamine-rl) (1.25.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /opt/conda/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow>=2.2.0->dopamine-rl) (2020.6.20)
# Collecting toolz>=0.9.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/12/f5/537e55f8ba664ff2a26f26913010fb0fcb98b6bbadc6158af888184fd0b7/toolz-0.11.1-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 17.4 MB/s eta 0:00:01
# Collecting dm-tree>=0.1.5
#   Downloading http://mirrors.tencentyun.com/pypi/packages/b2/b4/8ef1676bfca9fde09234058138416193b93f4eaf50bf17fb9c4abd141f11/dm_tree-0.1.6-cp36-cp36m-manylinux2014_x86_64.whl (115 kB)
#      |████████████████████████████████| 115 kB 32.2 MB/s eta 0:00:01
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /opt/conda/envs/python3/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.5->tensorflow>=2.2.0->dopamine-rl) (3.1.0)
# Collecting oauthlib>=3.0.0
#   Downloading http://mirrors.tencentyun.com/pypi/packages/e8/5d/9dd1c29e5a786525f6342f6c1d812ed2e37edc653ad297048c1668988053/oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 15.9 MB/s eta 0:00:01
# Collecting pyasn1>=0.1.3
#   Downloading http://mirrors.tencentyun.com/pypi/packages/62/1e/a94a8d635fa3ce4cfc7f506003548d0a2447ae76fd5ca53932970fe3053f/pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 17.6 MB/s eta 0:00:01
# Building wheels for collected packages: gym, jax, termcolor, wrapt
#   Building wheel for gym (setup.py) ... done
#   Created wheel for gym: filename=gym-0.18.3-py3-none-any.whl size=1657516 sha256=6d0561acc06c16939edee07dfa92157df6b15c1935d4c988f6626cbb12365aad
#   Stored in directory: /home/tione/.cache/pip/wheels/b3/66/fe/a9cbde33faadf0e759b7078d5c0f01dc4319857702f3d626e8
#   Building wheel for jax (setup.py) ... done
#   Created wheel for jax: filename=jax-0.2.16-py3-none-any.whl size=784391 sha256=2f8a3d12249642412e4277a754f4ad36ae59964d91554ae3ebe04e0ec4c2b28c
#   Stored in directory: /home/tione/.cache/pip/wheels/cc/0e/e8/d5ac7b238114b24846cf369a89965f10ddf3c7a7b4327cf20d
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=4b0c39128bae4215c3719d75b49cc306230ceacdbd33aae7020e279a3d9fa997
#   Stored in directory: /home/tione/.cache/pip/wheels/f5/e8/bb/9ba8210b306904d1c4b0447e63b144e324619f3a5a9f5507e5
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp36-cp36m-linux_x86_64.whl size=69810 sha256=43b3f46a2b37bdc52ebc39ac75aa64964fe929fa7a1d7fa5a928e6abf3f4bf5d
#   Stored in directory: /home/tione/.cache/pip/wheels/d2/fd/f4/c114a2e91e6bcbdfc1e4601b0c0e6a59147b8a3b9289bd2f75
# Successfully built gym jax termcolor wrapt
# ERROR: tensorflow 2.5.0 has requirement numpy~=1.19.2, but you'll have numpy 1.18.5 which is incompatible.
# Installing collected packages: pyglet, Pillow, cloudpickle, atari-py, opencv-python, gym, google-pasta, keras-preprocessing, tensorboard-plugin-wit, markdown, oauthlib, requests-oauthlib, pyasn1, rsa, cachetools, pyasn1-modules, google-auth, google-auth-oauthlib, wheel, dataclasses, werkzeug, absl-py, tensorboard-data-server, grpcio, tensorboard, gast, tensorflow-estimator, flatbuffers, opt-einsum, keras-nightly, astunparse, termcolor, wrapt, h5py, tensorflow, toolz, jax, jaxlib, dm-tree, chex, optax, msgpack, flax, pygame, tf-slim, gin-config, dopamine-rl
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.34.2
#     Uninstalling wheel-0.34.2:
#       Successfully uninstalled wheel-0.34.2
# Successfully installed Pillow-8.2.0 absl-py-0.13.0 astunparse-1.6.3 atari-py-0.2.9 cachetools-4.2.2 chex-0.0.7 cloudpickle-1.6.0 dataclasses-0.8 dm-tree-0.1.6 dopamine-rl-3.1.14 flatbuffers-1.12 flax-0.3.4 gast-0.4.0 gin-config-0.4.0 google-auth-1.32.0 google-auth-oauthlib-0.4.4 google-pasta-0.2.0 grpcio-1.34.1 gym-0.18.3 h5py-3.1.0 jax-0.2.16 jaxlib-0.1.68 keras-nightly-2.5.0.dev2021032900 keras-preprocessing-1.1.2 markdown-3.3.4 msgpack-1.0.2 oauthlib-3.1.1 opencv-python-4.5.2.54 opt-einsum-3.3.0 optax-0.0.8 pyasn1-0.4.8 pyasn1-modules-0.2.8 pygame-2.0.1 pyglet-1.5.15 requests-oauthlib-1.3.0 rsa-4.7.2 tensorboard-2.5.0 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.0 tensorflow-2.5.0 tensorflow-estimator-2.5.0 termcolor-1.1.0 tf-slim-1.1.0 toolz-0.11.1 werkzeug-2.0.1 wheel-0.36.2 wrapt-1.12.1

# %%
# @title Install Atari ROMS from google drive
# !python -m atari_py.import_roms drive/MyDrive/Dopamine-need\ experiments/ROMS

# %%
# @title Necessary imports and globals.

import numpy as np
import os
from dopamine.agents.dqn import dqn_agent
from dopamine.discrete_domains import run_experiment
from dopamine.colab import utils as colab_utils
from absl import flags
import gin.tf

BASE_PATH = '/tmp/colab_dope_run'  # @param
GAME = 'Asterix'  # @param

# %%
# @title Load baseline data
# !gsutil -q -m cp -R gs://download-dopamine-rl/preprocessed-benchmarks/* /content/
experimental_data = colab_utils.load_baselines('/content')

# %%
# @title Create an agent based on DQN, but choosing actions randomly.

LOG_PATH = os.path.join(BASE_PATH, 'random_dqn', GAME)

class MyRandomDQNAgent(dqn_agent.DQNAgent):
  def __init__(self, sess, num_actions):
    """This maintains all the DQN default argument values."""
    super().__init__(sess, num_actions)

  def step(self, reward, observation):
    """Calls the step function of the parent class, but returns a random action.
    """
    super().step(reward, observation)
    return np.random.randint(self.num_actions)

def create_random_dqn_agent(sess, environment, summary_writer=None):
  """The Runner class will expect a function of this type to create an agent."""
  return MyRandomDQNAgent(sess, num_actions=environment.action_space.n)

random_dqn_config = """
import dopamine.discrete_domains.atari_lib
import dopamine.discrete_domains.run_experiment
atari_lib.create_atari_environment.game_name = '{}'
atari_lib.create_atari_environment.sticky_actions = True
run_experiment.Runner.num_iterations = 200
run_experiment.Runner.training_steps = 10
run_experiment.Runner.max_steps_per_episode = 100
""".format(GAME)
gin.parse_config(random_dqn_config, skip_unknown=False)

# Create the runner class with this agent. We use very small numbers of steps
# to terminate quickly, as this is mostly meant for demonstrating how one can
# use the framework.
random_dqn_runner = run_experiment.TrainRunner(LOG_PATH, create_random_dqn_agent)

# %%
# @title Train MyRandomDQNAgent.
print('Will train agent, please be patient, may be a while...')
random_dqn_runner.run_experiment()
print('Done training!')

# %%
# @title Load the training logs.
random_dqn_data = colab_utils.read_experiment(
    LOG_PATH, verbose=True, summary_keys=['train_episode_returns'])
random_dqn_data['agent'] = 'MyRandomDQN'
random_dqn_data['run_number'] = 1
experimental_data[GAME] = experimental_data[GAME].merge(random_dqn_data, how='outer')

# %%
# @title Plot training results.

import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(16,8))
sns.lineplot(
    x='iteration', y='train_episode_returns', hue='agent',
    data=experimental_data[GAME], ax=ax)
plt.title(GAME)
plt.show()
